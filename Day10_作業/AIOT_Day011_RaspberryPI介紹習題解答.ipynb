# %% [markdown]
# ### 作業1
#
# ---

# %% [markdown]
# 觀察Raspberry PI OS桌面與純文字版本映像檔案的檔案大小，實際下載之後解壓縮，紀錄實際下載與解壓縮的時間。

# %% [markdown]
# ### **解答1**
#
# ---

# %% [markdown]
# 至 https://www.raspberrypi.org/downloads/raspberry-pi-os/ 下載 raspberry PI 開機映像檔案

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 下載
# Raspberry Pi OS (32-bit) with desktop and recommended software
# Image with desktop and recommended software based on Debian Buster,Version:August 2020
# Release date:2020-08-20
# Kernel version:5.4
# Size:2531 MB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 下載之後解壓至.img檔案，使用[etcher](https://www.balena.io/etcher/)燒錄至sdcard，紀錄時間

# %% [markdown]
# 下載
# Raspberry Pi OS (32-bit) Lite
# Minimal image based on Debian Buster, Version:August 2020
# Release date:2020-08-20
# Kernel version:5.4
# Size:435 MB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 下載之後解壓至.img檔案，使用[etcher](https://www.balena.io/etcher/)燒錄至sdcard，紀錄時間

# %% [markdown]
# ### 作業2
#
# ---

# %% [markdown]
# Raspberry PI OS開機後會自動的將sdcard的硬碟空間擴展成SDCard所有的區域，觀察開機的過程，確定可以順利的開機並且使用內定的帳號pi，密碼raspberry登入系統。

# %% [markdown]
# ### **解答2**
#
# ---

# %% [markdown]
# 此題希望同學可以成功地確定使用Raspberry PI開機，並且觀察開機過程中，系統畫面的開機流程。

# %% [markdown]
# ### 作業3
#
# ---

# %% [markdown]
# 練習設定pi無線網路，確定pi的網路可以穩定的連線至無線基地台，順利的取得無線基地台發送的ip與網路設定，並且啟動瀏覽器順利上網。

# %% [markdown]
# ### **解答3**
#
# ---

# %% [markdown]
# 點選由上角網路設定的圖示，選擇要連線的SSID，之後會需要輸入無線基地台的密碼。啟動瀏覽器，確定網路運作正常。
